# %% [markdown]
# # Module Turtle

# %% [raw]
# Essayer ces quelques commandes pour comprendre l'utilisation du module turtle :

# %%
from turtle import *
forward(120)
left(90)
color("red")
forward(80)

# %% [raw]
# Puis :

# %%
from turtle import *
forward(120)
left(90)
color("red")
forward(80)
reset()

# %% [markdown]
# ## Difficulté 1

# %% [raw]
# Tracer un carré de 100 pixels de côté.

# %% [markdown]
# ![01.jpg](attachment:01.jpg)

# %%
from turtle import *
forward(100)
#à compléter

# %% [raw]
# Tracer la figure ci-dessous. Chaque carré fait 100 pixels de côté.

# %% [markdown]
# ![02.jpg](attachment:02.jpg)

# %%
from turtle import *
#à compléter

# %% [raw]
# Tracer la figure ci-dessous. Le carré fait 100 pixels de côté.

# %% [markdown]
# ![03.jpg](attachment:03.jpg)

# %%
from turtle import *
#à compléter

# %% [raw]
# Tracer la figure ci-dessous. Le carré fait 100 pixels de côté.

# %% [markdown]
# ![04.jpg](attachment:04.jpg)

# %%
from turtle import *
#à compléter

# %% [markdown]
# ## Difficulté 2

# %% [raw]
# Tracer le cristal ci-dessous. Les grands segments mesurent 300 pixels, les petits 150.

# %% [markdown]
# ![05.jpg](attachment:05.jpg)

# %%
from turtle import *
#à compléter

# %% [raw]
# Tracer le cristal cidessous. Les grands segments mesurent 300 pixels, les petits 150.

# %% [markdown]
# ![06.jpg](attachment:06.jpg)

# %%
from turtle import *
#à compléter

# %% [raw]
# Tracer l’hexagone ci-dessous. Les 6 côtés mesurent 100 pixels.

# %% [markdown]
# ![07.jpg](attachment:07.jpg)

# %%
from turtle import *
#à compléter

# %% [raw]
# Tracer l'octogone ci-dessous. Les 8 côtés mesurent 100 pixels.

# %% [markdown]
# ![08.jpg](attachment:08.jpg)

# %%
from turtle import *
#à compléter

# %%
Tracer le déacagone cidessous.

# %% [markdown]
# ![09.jpg](attachment:09.jpg)

# %%
from turtle import *
#à compléter

# %%
Tracer un double déacagone.

# %%
from turtle import *
#à compléter

# %% [raw]
# Tracer le cercle ci-dessous.

# %% [markdown]
# ![10.jpg](attachment:10.jpg)

# %%
from turtle import *
#à compléter

# %% [markdown]
# ## Difficulté 3

# %%
Dans chaque cas, reproduire les dessins :

# %% [markdown]
# ![11.jpg](attachment:11.jpg)

# %%
from turtle import *
#à compléter

# %% [markdown]
# ![12.jpg](attachment:12.jpg)

# %%
from turtle import *
#à compléter

# %% [markdown]
# ![13.jpg](attachment:13.jpg)

# %%
from turtle import *
#à compléter

# %% [markdown]
# ![14.jpg](attachment:14.jpg)

# %%
from turtle import *
#à compléter

# %% [markdown]
# ![15.jpg](attachment:15.jpg)

# %%
from turtle import *
#à compléter

# %% [markdown]
# ![16.jpg](attachment:16.jpg)

# %%
from turtle import *
#à compléter

# %% [markdown]
# ![17.jpg](attachment:17.jpg)

# %%
from turtle import *
#à compléter
